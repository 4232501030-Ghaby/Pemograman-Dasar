# %% [markdown]
# <a href="https://colab.research.google.com/github/4232501030-Ghaby/Pemograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Ghaby pattama sinaga"
umur = 19
jurusan = "elektro"
prodi = "TRPE"
semester = 3
matakuliah = 'Pemograman dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Ghaby pattama sinaga
# 19
# elektro
# TRPE
# 3
# Pemograman dasar
# False
