# %% [markdown]
# <a href="https://colab.research.google.com/github/4232501030-Ghaby/Pemograman-Dasar/blob/main/contoh1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 1
x = 2
x = "ghaby"
b = 8.6
c = True
d = False

nama ="ghaby"
nim = 4232501030

#list
mahasiswa = ["ghaby" , 4232501030 , 160.3 ,False]
print ("nama :", mahasiswa [0])
print ("nim:", mahasiswa [1])

print (x)
#cara satu per satu
print (type(x))
print (type(b))
print (type(c))
print (type(d))

#cara digabung
print (type(x)), (type(b)), (type(c)),(type(d))

#tuple

mobil = ("avanza", 2020, 1500000)
# Out:
# nama : ghaby
# nim: 4232501030
# ghaby
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>
